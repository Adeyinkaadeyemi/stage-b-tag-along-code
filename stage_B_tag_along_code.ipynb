# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
'''
Correlation is a measure used to describe the linear relationship between two variables
A situation where two or more of the predictors have a strong correlation is known as multicollinearity.
for a perfect positive correlation (both variables increase or decrease together
for a perfect negative correlation (an increase in one variable causes a decrease in the other variable
A correlation value of 0 indicates that there is absolutely no correlation between both variables
The parameters that define the model architecture are referred to as hyperparameters
while the process of exploring a range of values is called hyperparameter tuning.
A polynomial regression model is considered a linear regression model that can be used when a curvilinear relationship exists between the predictors and the response variable.'''

''' A polynomial regression model is considered a linear regression model that can be used when a curvilinear relationship exists between the predictors and the response variable'''

# %%
data = pd.read_csv ('/content/drive/MyDrive/ALL DATASET/energydata_complete.csv')
data.describe(include='all')
# Out:
#                        date    Appliances        lights            T1  \
# count                 19735  19735.000000  19735.000000  19735.000000
# unique                19735           NaN           NaN           NaN
# top     2016-01-11 17:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN     97.694958      3.801875     21.686571
# std                     NaN    102.524891      7.935988      1.606066
# min                     NaN     10.000000      0.000000     16.790000
# 25%                     NaN     50.000000      0.000000     20.760000
# 50%                     NaN     60.000000      0.000000     21.600000
# 75%                     NaN    100.000000      0.000000     22.600000
# max                     NaN   1080.000000     70.000000     26.260000
#
#                 RH_1            T2          RH_2            T3          RH_3  \
# ...

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
data.shape
# Out:
# (19735, 29)

# %%
df = pd.DataFrame(data = data, columns= data.Appliances )
print(df.describe)
# Out:
# <bound method NDFrame.describe of Appliances  60   60   50   50   60   50   60   60   60   70   ...  220  180  \
# 0           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 3           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 4           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 19730       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 19731       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 19732       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 19733       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 19734       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
# ...

# %%
train  = data.drop(['date', 'lights'], axis=1)
test = data['Appliances']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, test,
test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
features_data = normalised_data.drop(columns=['date','light'])
heating_target = normalised_data['Apliances']
# Out:
#   File "<ipython-input-20-48243db5a8d3>", line 3
#     normalised_data = pd.DataFrame(scaler.fit_transform(data), columns=''date'',''light'')
#                                                                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
regss = LinearRegression()

# %%
regss.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predct= regss.predict(X_train)
print(predct)
# Out:
# [ 50.  60.  50. ...  60. 210.  50.]

# %%
regss.score(X_train, y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
